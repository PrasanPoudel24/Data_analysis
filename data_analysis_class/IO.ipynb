# %% [markdown]
# # Import external files
# - csv,tsv

# %% [markdown]
# # Using CSV

# %%
import pandas as pd
import numpy as np

# %%
# to read csv : pd.read_csv()
# index_col : set colum as index
#usecols :only show required col
df= pd.read_csv('aug_train.csv', index_col='enrollee_id',usecols=['enrollee_id','city','city_development_index','gender'])
df
# Out:
#                  city  city_development_index gender
# enrollee_id
# 8949         city_103                   0.920   Male
# 29725         city_40                   0.776   Male
# 11561         city_21                   0.624    NaN
# 33241        city_115                   0.789    NaN
# 666          city_162                   0.767   Male
# ...               ...                     ...    ...
# 7386         city_173                   0.878   Male
# 31398        city_103                   0.920   Male
# 24576        city_103                   0.920   Male
# 5756          city_65                   0.802   Male
# 23834         city_67                   0.855    NaN
#
# [19158 rows x 3 columns]

# %%
#select n rows while read data
#nrows : only read  required no of rows
df_new = pd.read_csv("aug_train.csv",nrows=1000)
df_new
# Out:
#      enrollee_id      city  city_development_index  gender  \
# 0           8949  city_103                   0.920    Male
# 1          29725   city_40                   0.776    Male
# 2          11561   city_21                   0.624     NaN
# 3          33241  city_115                   0.789     NaN
# 4            666  city_162                   0.767    Male
# ..           ...       ...                     ...     ...
# 995        28500   city_21                   0.624     NaN
# 996        10371  city_103                   0.920  Female
# 997        10028   city_73                   0.754    Male
# 998        29671   city_40                   0.776    Male
# 999         4482  city_103                   0.920    Male
#
#          relevent_experience enrolled_university education_level  \
# 0    Has relevent experience       no_enrollment        Graduate
# 1     No relevent experience       no_enrollment        Graduate
# ...

# %%
# separate parameter : \,\t
# names : define column names
tab_df=pd.read_csv("movie_titles_metadata.tsv",sep="\t",names=['S.N','Title','Released year','Ratings','Reviews','Genre'],index_col="S.N")
tab_df
# Out:
#                            Title Released year  Ratings   Reviews  \
# S.N
# m0    10 things i hate about you          1999      6.9   62847.0
# m1    1492: conquest of paradise          1992      6.2   10421.0
# m2                    15 minutes          2001      6.1   25854.0
# m3         2001: a space odyssey          1968      8.4  163227.0
# m4                       48 hrs.          1982      6.9   22289.0
# ...                          ...           ...      ...       ...
# m612                    watchmen          2009      7.8  135229.0
# m613                         xxx          2002      5.6   53505.0
# m614                       x-men          2000      7.4  122149.0
# m615          young frankenstein          1974      8.0   57618.0
# m616                   zulu dawn          1979      6.4    1911.0
#
#                                                   Genre
# S.N
# m0                                 ['comedy' 'romance']
# ...

# %%
#parse_date : convert to date
ipl_df=pd.read_csv("IPL Matches 2008-2020.csv",parse_dates=["date"])
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
zomato_df=pd.read_csv("zomato.csv",encoding='latin_1')
zomato_df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # to write data in csv file

# %%
ipl_opt=ipl_df[['city','date','venue','winner']]
ipl_opt
# Out:
#            city       date                                       venue  \
# 0     Bangalore 2008-04-18                       M Chinnaswamy Stadium
# 1    Chandigarh 2008-04-19  Punjab Cricket Association Stadium, Mohali
# 2         Delhi 2008-04-19                            Feroz Shah Kotla
# 3        Mumbai 2008-04-20                            Wankhede Stadium
# 4       Kolkata 2008-04-20                                Eden Gardens
# ..          ...        ...                                         ...
# 811       Dubai 2020-09-28         Dubai International Cricket Stadium
# 812       Dubai 2020-11-05         Dubai International Cricket Stadium
# 813   Abu Dhabi 2020-11-06                        Sheikh Zayed Stadium
# 814   Abu Dhabi 2020-11-08                        Sheikh Zayed Stadium
# 815       Dubai 2020-11-10         Dubai International Cricket Stadium
#
#                           winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# ...

# %%
# to_csv : to writing the file
ipl_opt.to_csv('ipl_opt.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # to_csv : to writing the file
# ----> 2 ipl_opt.to_csv('ipl_opt.csv')
#
# NameError: name 'ipl_opt' is not defined

# %% [markdown]
# # Excel file

# %%
# to write in excel file
ipl_opt.to_excel('ipl.xlsx',sheet_name='ipl_data')

# %%
# to read excel file
pd.read_excel("ipl.xlsx",sheet_name='ipl_data')
# Out:
#      Unnamed: 0        city       date  \
# 0             0   Bangalore 2008-04-18
# 1             1  Chandigarh 2008-04-19
# 2             2       Delhi 2008-04-19
# 3             3      Mumbai 2008-04-20
# 4             4     Kolkata 2008-04-20
# ..          ...         ...        ...
# 811         811       Dubai 2020-09-28
# 812         812       Dubai 2020-11-05
# 813         813   Abu Dhabi 2020-11-06
# 814         814   Abu Dhabi 2020-11-08
# 815         815       Dubai 2020-11-10
#
#                                           venue                       winner
# 0                         M Chinnaswamy Stadium        Kolkata Knight Riders
# 1    Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 2                              Feroz Shah Kotla             Delhi Daredevils
# 3                              Wankhede Stadium  Royal Challengers Bangalore
# 4                                  Eden Gardens        Kolkata Knight Riders
# ...

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
print(req)
data = StringIO(req.text)
print(data)

pd.read_csv(data)
# Out:
# <Response [200]>
# ...
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# # functions

# %%
aug_train=pd.read_csv('aug_train.csv')
aug_train
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
#.head(n) : n=5, depends on n value
aug_train.head(100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %%
# .tail for bottom 
aug_train.tail()
# Out:
#        enrollee_id      city  city_development_index gender  \
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size company_type last_new_job  \
# 19153       Humanities         14          NaN          NaN            1
# ...

# %%
# random selection: .sample() : default 1 random row , otherwise n
aug_train.sample(10)
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 12566        17758  city_103                   0.920    Male
# 4320         10303  city_103                   0.920    Male
# 13982        32108  city_103                   0.920     NaN
# 16704        29363   city_46                   0.762    Male
# 11746        17097  city_103                   0.920    Male
# 3791          4711   city_13                   0.827    Male
# 12431        32008   city_71                   0.884    Male
# 4880         20177  city_103                   0.920    Male
# 8258         12948   city_16                   0.910     NaN
# 4490         11934  city_160                   0.920  Female
#
#            relevent_experience enrolled_university education_level  \
# 12566  Has relevent experience       no_enrollment        Graduate
# 4320   Has relevent experience    Full time course         Masters
# 13982  Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # to dispaly overall information of data

# %%
aug_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  category
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
aug_train.gender=aug_train.gender.astype('category')

# %% [markdown]
# # statistical information

# %%
# include = 'all' :help to check for all type of object
aug_train.describe(include = 'all' )
# Out:
#          enrollee_id      city  city_development_index gender  \
# count   19158.000000     19158            19158.000000  14650
# unique           NaN       123                     NaN      3
# top              NaN  city_103                     NaN   Male
# freq             NaN      4355                     NaN  13221
# mean    16875.358179       NaN                0.828848    NaN
# std      9616.292592       NaN                0.123362    NaN
# min         1.000000       NaN                0.448000    NaN
# 25%      8554.250000       NaN                0.740000    NaN
# 50%     16982.500000       NaN                0.903000    NaN
# 75%     25169.750000       NaN                0.920000    NaN
# max     33380.000000       NaN                0.949000    NaN
#
#             relevent_experience enrolled_university education_level  \
# count                     19158               18772           18698
# unique                        2                   3               5
# ...

# %%
aug_train.city_development_index.quantile(0.25)
# Out:
# np.float64(0.74)

# %% [markdown]
# # to sort data

# %%
#aug_train.sort_index() no change
aug_train.set_index('enrollee_id').sort_index(ascending=False)
# Out:
#                  city  city_development_index  gender  \
# enrollee_id
# 33380         city_83                   0.923    Male
# 33379        city_103                   0.920    Male
# 33377         city_65                   0.802    Male
# 33376         city_16                   0.910  Female
# 33375        city_103                   0.920    Male
# ...               ...                     ...     ...
# 7            city_136                   0.897    Male
# 5             city_67                   0.855    Male
# 4            city_103                   0.920    Male
# 2            city_103                   0.920    Male
# 1            city_103                   0.920    Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 33380         No relevent experience       no_enrollment        Graduate
# 33379        Has relevent experience       no_enrollment        Graduate
# ...

# %%
# to display columns name
list_col=aug_train.columns
list_col
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
# total numbers of rows
len(aug_train)
# Out:
# 19158

# %%
#shape of DF
aug_train.shape
# Out:
# (19158, 14)

# %%
no_rows = aug_train.shape[0]
no_cols=aug_train.shape[1]

# %%
print(f"there are {no_rows} rows and {no_cols} coloumns")
# Out:
# there are 19158 rows and 14 coloumns

# %% [markdown]
# # checking Null values

# %%
null_checking=aug_train.isnull().sum()

# %%
per_che=null_checking/len(aug_train)*100
per_che
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     0.000000
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# last_new_job               2.207955
# training_hours             0.000000
# target                     0.000000
# dtype: float64

# %%
per_che.sort_values(ascending=False)
# Out:
# company_type              32.049274
# company_size              30.994885
# gender                    23.530640
# major_discipline          14.683161
# education_level            2.401086
# last_new_job               2.207955
# enrolled_university        2.014824
# experience                 0.339284
# enrollee_id                0.000000
# city                       0.000000
# relevent_experience        0.000000
# city_development_index     0.000000
# training_hours             0.000000
# target                     0.000000
# dtype: float64

# %%
# checking duplicates datas
aug_train.duplicated().any()
# Out:
# np.False_

# %%
aug_train.drop(columns='enrollee_id').duplicated().any()
# Out:
# np.True_

# %%
aug_train.city_development_index.mean()
# Out:
# np.float64(0.8288480008351603)

# %%
# num of unique values
aug_train.gender.nunique()
# Out:
# 3

# %%
# unique values list
aug_train.gender.unique()
# Out:
# ['Male', NaN, 'Female', 'Other']
# Categories (3, object): ['Female', 'Male', 'Other']

# %%
#checking frequency of each unique values
aug_train.gender.value_counts()
# Out:
# gender
# Male      13221
# Female     1238
# Other       191
# Name: count, dtype: int64

# %% [markdown]
# # apply boolean condition

# %%
# training hour > 30 in graduation level
aug_train[(aug_train.training_hours<30)&('Graduate'==aug_train.education_level)]
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 5            21651  city_176                   0.764     NaN
# 7              402   city_46                   0.762    Male
# 12           25619   city_61                   0.913    Male
# 15            6588  city_114                   0.926    Male
# 17            5764   city_21                   0.624     NaN
# ...            ...       ...                     ...     ...
# 19139         5603   city_21                   0.624     NaN
# 19141         7782   city_23                   0.899    Male
# 19143        33047  city_103                   0.920    Male
# 19150        32313  city_160                   0.920  Female
# 19152        29754  city_103                   0.920  Female
#
#            relevent_experience enrolled_university education_level  \
# 5      Has relevent experience    Part time course        Graduate
# 7      Has relevent experience       no_enrollment        Graduate
# ...

# %%
aug_train.query('training_hours<30 and education_level=="Graduate"')#from query
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 5            21651  city_176                   0.764     NaN
# 7              402   city_46                   0.762    Male
# 12           25619   city_61                   0.913    Male
# 15            6588  city_114                   0.926    Male
# 17            5764   city_21                   0.624     NaN
# ...            ...       ...                     ...     ...
# 19139         5603   city_21                   0.624     NaN
# 19141         7782   city_23                   0.899    Male
# 19143        33047  city_103                   0.920    Male
# 19150        32313  city_160                   0.920  Female
# 19152        29754  city_103                   0.920  Female
#
#            relevent_experience enrolled_university education_level  \
# 5      Has relevent experience    Part time course        Graduate
# 7      Has relevent experience       no_enrollment        Graduate
# ...
