# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
null_check = titanic.isnull().sum(axis=1) / titanic.shape[1] * 100

# %%
null_check
# Out:
# 0       8.333333
# 1       0.000000
# 2       8.333333
# 3       0.000000
# 4       8.333333
#          ...
# 886     8.333333
# 887     0.000000
# 888    16.666667
# 889     0.000000
# 890     8.333333
# Length: 891, dtype: float64

# %%
null_check>5
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.drop(columns=['Cabin'],inplace=True)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
null_check = titanic.isnull().sum(axis=1) / titanic.shape[1] * 100
null_check
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 886    0.000000
# 887    0.000000
# 888    9.090909
# 889    0.000000
# 890    0.000000
# Length: 891, dtype: float64

# %%
null_check<5
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Length: 891, dtype: bool

# %%
null_check.reset_index()
# Out:
#      index         0
# 0        0  0.000000
# 1        1  0.000000
# 2        2  0.000000
# 3        3  0.000000
# 4        4  0.000000
# ..     ...       ...
# 886    886  0.000000
# 887    887  0.000000
# 888    888  9.090909
# 889    889  0.000000
# 890    890  0.000000
#
# [891 rows x 2 columns]

# %%
null_check[null_check>5]
# Out:
# 5      9.090909
# 17     9.090909
# 19     9.090909
# 26     9.090909
# 28     9.090909
#          ...
# 859    9.090909
# 863    9.090909
# 868    9.090909
# 878    9.090909
# 888    9.090909
# Length: 179, dtype: float64

# %%
null_index=null_check[null_check>5].index

# %%
null_index
# Out:
# Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#        ...
#        832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#       dtype='int64', length=179)

# %%
titanic.drop(null_index)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.drop(columns='PassengerId',inplace=True)

# %%
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
titanic.dropna()
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
titanic.Sex.mode()[0]#most frequently used
# Out:
# 'male'

# %%
titanic.Sex.fillna('others')
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
titanic.isnull().sum(axis=1) / titanic.shape[0] * 100
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 886    0.000000
# 887    0.000000
# 888    0.112233
# 889    0.000000
# 890    0.000000
# Length: 891, dtype: float64

# %%
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
aug_train=pd.read_csv('aug_train.csv')

# %%
aug_train
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
aug_train[aug_train.drop(columns='enrollee_id').duplicated()]
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 250           6685   city_16                   0.910    Male
# 3924         25835  city_159                   0.843    Male
# 4078          3015   city_16                   0.910    Male
# 4212          1686  city_103                   0.920    Male
# 4649         23517  city_103                   0.920    Male
# 5554         19041  city_103                   0.920    Male
# 6292         29930  city_103                   0.920    Male
# 6851          3736  city_160                   0.920    Male
# 7108         27402  city_103                   0.920    Male
# 7253         23179  city_103                   0.920    Male
# 7376         19320  city_103                   0.920    Male
# 7550          9755   city_21                   0.624    Male
# 7909          8569  city_103                   0.920    Male
# 7930         32121  city_103                   0.920    Male
# ...

# %%
aug_train[aug_train.drop(columns='enrollee_id').duplicated(keep=False)]
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 67            9645   city_16                   0.910    Male
# 250           6685   city_16                   0.910    Male
# 270          22319   city_21                   0.624    Male
# 321          20376  city_160                   0.920    Male
# 563           5911  city_103                   0.920    Male
# ...            ...       ...                     ...     ...
# 18721        27500  city_103                   0.920    Male
# 18758        29272   city_21                   0.624    Male
# 19019        26349  city_103                   0.920    Male
# 19056        26961  city_103                   0.920  Female
# 19143        33047  city_103                   0.920    Male
#
#            relevent_experience enrolled_university education_level  \
# 67     Has relevent experience       no_enrollment        Graduate
# 250    Has relevent experience       no_enrollment        Graduate
# ...

# %%
ipl=pd.read_csv('ipl_opt.csv')

# %%
ipl
# Out:
#      Unnamed: 0       id        city        date player_of_match  \
# 0             0   335982   Bangalore  2008-04-18     BB McCullum
# 1             1   335983  Chandigarh  2008-04-19      MEK Hussey
# 2             2   335984       Delhi  2008-04-19     MF Maharoof
# 3             3   335985      Mumbai  2008-04-20      MV Boucher
# 4             4   335986     Kolkata  2008-04-20       DJ Hussey
# ..          ...      ...         ...         ...             ...
# 811         811  1216547       Dubai  2020-09-28  AB de Villiers
# 812         812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813         813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814         814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815         815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# ...

# %%
ipl.winner
# Out:
# 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 811    Royal Challengers Bangalore
# 812                 Mumbai Indians
# 813            Sunrisers Hyderabad
# 814                 Delhi Capitals
# 815                 Mumbai Indians
# Name: winner, Length: 816, dtype: object

# %%
ipl.player_of_match
# Out:
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
#             ...
# 811    AB de Villiers
# 812         JJ Bumrah
# 813     KS Williamson
# 814        MP Stoinis
# 815          TA Boult
# Name: player_of_match, Length: 816, dtype: object

# %%
ipl.player_of_match.str.split(',')
# Out:
# 0         [BB McCullum]
# 1          [MEK Hussey]
# 2         [MF Maharoof]
# 3          [MV Boucher]
# 4           [DJ Hussey]
#              ...
# 811    [AB de Villiers]
# 812         [JJ Bumrah]
# 813     [KS Williamson]
# 814        [MP Stoinis]
# 815          [TA Boult]
# Name: player_of_match, Length: 816, dtype: object

# %% [markdown]
# ## strip() – remove from both sides
# ## lstrip() – remove from left side only
# ## rstrip() – remove from right side only

# %% [markdown]
# ## string methods used to remove unwanted characters

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
def billcategory(amt):
    if amt<10:
        return "LOW"
    elif amt>10 and amt<30:
        return "mid"
    else:
        return "high"

# %%
tips['bill_category']=tips.total_bill.apply(billcategory)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size bill_category
# 0         16.99  1.01  Female     No   Sun  Dinner     2           mid
# 1         10.34  1.66    Male     No   Sun  Dinner     3           mid
# 2         21.01  3.50    Male     No   Sun  Dinner     3           mid
# 3         23.68  3.31    Male     No   Sun  Dinner     2           mid
# 4         24.59  3.61  Female     No   Sun  Dinner     4           mid
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3           mid
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2           mid
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           mid
# 242       17.82  1.75    Male     No   Sat  Dinner     2           mid
# 243       18.78  3.00  Female     No  Thur  Dinner     2           mid
#
# [244 rows x 8 columns]

# %%
tips.groupby('day',observed=True)[['total_bill']].sum()
# Out:
#       total_bill
# day
# Thur     1096.33
# Fri       325.88
# Sat      1778.40
# Sun      1627.16
