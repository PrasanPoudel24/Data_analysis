# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("aug_train.csv",index_col=["enrollee_id"])
df
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %%
aug_train=pd.read_csv("aug_train.csv",nrows=300)
aug_train
# Out:
#      enrollee_id      city  city_development_index  gender  \
# 0           8949  city_103                   0.920    Male
# 1          29725   city_40                   0.776    Male
# 2          11561   city_21                   0.624     NaN
# 3          33241  city_115                   0.789     NaN
# 4            666  city_162                   0.767    Male
# ..           ...       ...                     ...     ...
# 295        12934  city_114                   0.926    Male
# 296        30400   city_73                   0.754    Male
# 297        26419   city_67                   0.855  Female
# 298         4188  city_103                   0.920     NaN
# 299        12117   city_74                   0.579    Male
#
#          relevent_experience enrolled_university education_level  \
# 0    Has relevent experience       no_enrollment        Graduate
# 1     No relevent experience       no_enrollment        Graduate
# ...

# %%
tap_df=pd.read_csv("movie_titles_metadata.tsv",sep="\t",names=["S.N","Title","Released year","Rating","Reviews","Genre"],index_col="S.N")
tap_df
# Out:
#                            Title Released year  Rating   Reviews  \
# S.N
# m0    10 things i hate about you          1999     6.9   62847.0
# m1    1492: conquest of paradise          1992     6.2   10421.0
# m2                    15 minutes          2001     6.1   25854.0
# m3         2001: a space odyssey          1968     8.4  163227.0
# m4                       48 hrs.          1982     6.9   22289.0
# ...                          ...           ...     ...       ...
# m612                    watchmen          2009     7.8  135229.0
# m613                         xxx          2002     5.6   53505.0
# m614                       x-men          2000     7.4  122149.0
# m615          young frankenstein          1974     8.0   57618.0
# m616                   zulu dawn          1979     6.4    1911.0
#
#                                                   Genre
# S.N
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# ...

# %%
tab_df=pd.read_csv("movie_titles_metadata.tsv",sep="\t",names=['S.N','Title','Released year','Ratings','Reviews','Genre'],index_col="S.N")
tab_df
# Out:
#                            Title Released year  Ratings   Reviews  \
# S.N
# m0    10 things i hate about you          1999      6.9   62847.0
# m1    1492: conquest of paradise          1992      6.2   10421.0
# m2                    15 minutes          2001      6.1   25854.0
# m3         2001: a space odyssey          1968      8.4  163227.0
# m4                       48 hrs.          1982      6.9   22289.0
# ...                          ...           ...      ...       ...
# m612                    watchmen          2009      7.8  135229.0
# m613                         xxx          2002      5.6   53505.0
# m614                       x-men          2000      7.4  122149.0
# m615          young frankenstein          1974      8.0   57618.0
# m616                   zulu dawn          1979      6.4    1911.0
#
#                                                   Genre
# S.N
# m0                                 ['comedy' 'romance']
# ...

# %%
tab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 617 entries, m0 to m616
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          616 non-null    object
#  1   Released year  616 non-null    object
#  2   Ratings        616 non-null    float64
#  3   Reviews        616 non-null    float64
#  4   Genre          616 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 28.9+ KB

# %%
ipl=pd.read_csv("IPL Matches 2008-2020.csv")
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
ipl=pd.read_csv("IPL Matches 2008-2020.csv",parse_dates=["date"])
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
ipl.to_csv('ipl_opt.csv')

# %%
ipl
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl_opt=ipl[["id","city","venue","winner","date"]]
ipl_opt
# Out:
#           id        city                                       venue  \
# 0     335982   Bangalore                       M Chinnaswamy Stadium
# 1     335983  Chandigarh  Punjab Cricket Association Stadium, Mohali
# 2     335984       Delhi                            Feroz Shah Kotla
# 3     335985      Mumbai                            Wankhede Stadium
# 4     335986     Kolkata                                Eden Gardens
# ..       ...         ...                                         ...
# 811  1216547       Dubai         Dubai International Cricket Stadium
# 812  1237177       Dubai         Dubai International Cricket Stadium
# 813  1237178   Abu Dhabi                        Sheikh Zayed Stadium
# 814  1237180   Abu Dhabi                        Sheikh Zayed Stadium
# 815  1237181       Dubai         Dubai International Cricket Stadium
#
#                           winner       date
# 0          Kolkata Knight Riders 2008-04-18
# 1            Chennai Super Kings 2008-04-19
# ...

# %%
ipl_opt.to_csv("ipl_new")

# %%
ipl_opt.to_excel('ipl_practise.xlsx',sheet_name="new_data")

# %%
new=pd.read_excel('ipl_practise.xlsx',sheet_name="new_data",index_col="id")
new
# Out:
#          Unnamed: 0        city                                       venue  \
# id
# 335982            0   Bangalore                       M Chinnaswamy Stadium
# 335983            1  Chandigarh  Punjab Cricket Association Stadium, Mohali
# 335984            2       Delhi                            Feroz Shah Kotla
# 335985            3      Mumbai                            Wankhede Stadium
# 335986            4     Kolkata                                Eden Gardens
# ...             ...         ...                                         ...
# 1216547         811       Dubai         Dubai International Cricket Stadium
# 1237177         812       Dubai         Dubai International Cricket Stadium
# 1237178         813   Abu Dhabi                        Sheikh Zayed Stadium
# 1237180         814   Abu Dhabi                        Sheikh Zayed Stadium
# 1237181         815       Dubai         Dubai International Cricket Stadium
#
#                               winner       date
# ...

# %%
new.drop(columns=["city"])
# Out:
#          Unnamed: 0                                       venue  \
# id
# 335982            0                       M Chinnaswamy Stadium
# 335983            1  Punjab Cricket Association Stadium, Mohali
# 335984            2                            Feroz Shah Kotla
# 335985            3                            Wankhede Stadium
# 335986            4                                Eden Gardens
# ...             ...                                         ...
# 1216547         811         Dubai International Cricket Stadium
# 1237177         812         Dubai International Cricket Stadium
# 1237178         813                        Sheikh Zayed Stadium
# 1237180         814                        Sheikh Zayed Stadium
# 1237181         815         Dubai International Cricket Stadium
#
#                               winner       date
# id
# 335982         Kolkata Knight Riders 2008-04-18
# 335983           Chennai Super Kings 2008-04-19
# ...

# %%
ipl
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl=pd.read_csv("IPL Matches 2008-2020.csv")
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
ipl
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl.set_index('date').sort_index()
# Out:
#                  id        city player_of_match  \
# date
# 2008-04-18   335982   Bangalore     BB McCullum
# 2008-04-19   335983  Chandigarh      MEK Hussey
# 2008-04-19   335984       Delhi     MF Maharoof
# 2008-04-20   335985      Mumbai      MV Boucher
# 2008-04-20   335986     Kolkata       DJ Hussey
# ...             ...         ...             ...
# 2020-11-03  1216495     Sharjah        S Nadeem
# 2020-11-05  1237177       Dubai       JJ Bumrah
# 2020-11-06  1237178   Abu Dhabi   KS Williamson
# 2020-11-08  1237180   Abu Dhabi      MP Stoinis
# 2020-11-10  1237181       Dubai        TA Boult
#
#                                                  venue  neutral_venue  \
# date
# 2008-04-18                       M Chinnaswamy Stadium              0
# 2008-04-19  Punjab Cricket Association Stadium, Mohali              0
# 2008-04-19                            Feroz Shah Kotla              0
# 2008-04-20                            Wankhede Stadium              0
# ...

# %%
null_checking=aug_train.isnull().sum()
null_checking
# Out:
# enrollee_id                0
# city                       0
# city_development_index     0
# gender                    77
# relevent_experience        0
# enrolled_university        7
# education_level            7
# major_discipline          42
# experience                 1
# company_size              85
# company_type              89
# last_new_job               6
# training_hours             0
# target                     0
# dtype: int64

# %%
null_checking.sort_values(ascending=False)
# Out:
# company_type              89
# company_size              85
# gender                    77
# major_discipline          42
# education_level            7
# enrolled_university        7
# last_new_job               6
# experience                 1
# enrollee_id                0
# city                       0
# relevent_experience        0
# city_development_index     0
# training_hours             0
# target                     0
# dtype: int64

# %% [markdown]
# # Data cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
aug_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             300 non-null    int64
#  1   city                    300 non-null    object
#  2   city_development_index  300 non-null    float64
#  3   gender                  223 non-null    object
#  4   relevent_experience     300 non-null    object
#  5   enrolled_university     293 non-null    object
#  6   education_level         293 non-null    object
#  7   major_discipline        258 non-null    object
#  8   experience              299 non-null    object
#  9   company_size            215 non-null    object
#  10  company_type            211 non-null    object
#  11  last_new_job            294 non-null    object
#  12  training_hours          300 non-null    int64
#  13  target                  300 non-null    float64
# ...

# %%
null=aug_train.isnull().sum()/len(aug_train)*100
null
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     0.000000
# gender                    25.666667
# relevent_experience        0.000000
# enrolled_university        2.333333
# education_level            2.333333
# major_discipline          14.000000
# experience                 0.333333
# company_size              28.333333
# company_type              29.666667
# last_new_job               2.000000
# training_hours             0.000000
# target                     0.000000
# dtype: float64

# %%
len(aug_train)
# Out:
# 300

# %%
aug_train
# Out:
#      enrollee_id      city  city_development_index  gender  \
# 0           8949  city_103                   0.920    Male
# 1          29725   city_40                   0.776    Male
# 2          11561   city_21                   0.624     NaN
# 3          33241  city_115                   0.789     NaN
# 4            666  city_162                   0.767    Male
# ..           ...       ...                     ...     ...
# 295        12934  city_114                   0.926    Male
# 296        30400   city_73                   0.754    Male
# 297        26419   city_67                   0.855  Female
# 298         4188  city_103                   0.920     NaN
# 299        12117   city_74                   0.579    Male
#
#          relevent_experience enrolled_university education_level  \
# 0    Has relevent experience       no_enrollment        Graduate
# 1     No relevent experience       no_enrollment        Graduate
# ...

# %%
null=aug_train.isnull().sum(axis=1)/aug_train.shape[1]*100
null
# Out:
# 0      14.285714
# 1       0.000000
# 2      21.428571
# 3      21.428571
# 4       0.000000
#          ...
# 295     0.000000
# 296     0.000000
# 297     0.000000
# 298     7.142857
# 299     0.000000
# Length: 300, dtype: float64

# %%
null>5
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298     True
# 299    False
# Length: 300, dtype: bool

# %%
null.reset_index()
# Out:
#      index          0
# 0        0  14.285714
# 1        1   0.000000
# 2        2  21.428571
# 3        3  21.428571
# 4        4   0.000000
# ..     ...        ...
# 295    295   0.000000
# 296    296   0.000000
# 297    297   0.000000
# 298    298   7.142857
# 299    299   0.000000
#
# [300 rows x 2 columns]

# %%
null>3
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298     True
# 299    False
# Length: 300, dtype: bool

# %%
null[null>3].index
# Out:
# Index([  0,   2,   3,   5,   6,   9,  10,  13,  14,  16,
#        ...
#        278, 280, 283, 286, 287, 289, 290, 291, 294, 298],
#       dtype='int64', length=151)

# %%
null=ipl.isnull().sum()

# %%
null_index=ipl.isnull().sum().index

# %%
ipl.drop(null_index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 ipl.drop(null_index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
zomato=pd.read_csv("zomato.csv",encoding="latin-1")
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
zomato.Cuisines=zomato.Cuisines.astype("category")
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   category
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
zomato.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool

# %%
ipl=pd.read_csv("IPL Matches 2008-2020.csv")
ipl
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl.set_index('date').sort_index(ascending=False)
# Out:
#                  id        city player_of_match  \
# date
# 2020-11-10  1237181       Dubai        TA Boult
# 2020-11-08  1237180   Abu Dhabi      MP Stoinis
# 2020-11-06  1237178   Abu Dhabi   KS Williamson
# 2020-11-05  1237177       Dubai       JJ Bumrah
# 2020-11-03  1216495     Sharjah        S Nadeem
# ...             ...         ...             ...
# 2008-04-20   335986     Kolkata       DJ Hussey
# 2008-04-20   335985      Mumbai      MV Boucher
# 2008-04-19   335984       Delhi     MF Maharoof
# 2008-04-19   335983  Chandigarh      MEK Hussey
# 2008-04-18   335982   Bangalore     BB McCullum
#
#                                                  venue  neutral_venue  \
# date
# 2020-11-10         Dubai International Cricket Stadium              0
# 2020-11-08                        Sheikh Zayed Stadium              0
# 2020-11-06                        Sheikh Zayed Stadium              0
# 2020-11-05         Dubai International Cricket Stadium              0
# ...

# %%
ipl.duplicated().any()
# Out:
# np.False_

# %%
ipl[('Kolkata'==ipl.city)&('bat'==ipl.toss_decision)].reset_index()
# Out:
#     index      id     city        date   player_of_match         venue  \
# 0       4  335986  Kolkata  2008-04-20         DJ Hussey  Eden Gardens
# 1      15  335997  Kolkata  2008-04-29     ST Jayasuriya  Eden Gardens
# 2      28  336010  Kolkata  2008-05-08        SC Ganguly  Eden Gardens
# 3      35  336017  Kolkata  2008-05-13     Shoaib Akhtar  Eden Gardens
# 4      43  336025  Kolkata  2008-05-18           M Ntini  Eden Gardens
# 5      52  336035  Kolkata  2008-05-25          Umar Gul  Eden Gardens
# 6     122  419113  Kolkata  2010-03-16          MS Dhoni  Eden Gardens
# 7     144  419135  Kolkata  2010-04-01        SC Ganguly  Eden Gardens
# 8     148  419139  Kolkata  2010-04-04  DPMD Jayawardene  Eden Gardens
# 9     153  419144  Kolkata  2010-04-07        SC Ganguly  Eden Gardens
# 10    167  419158  Kolkata  2010-04-17        JD Unadkat  Eden Gardens
# 11    170  419161  Kolkata  2010-04-19          M Kartik  Eden Gardens
# ...

# %%
ipl.drop(columns='neutral_venue')
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# ...

# %%
ipl=ipl.dropna()

# %%
ipl.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
ipl=pd.read_csv("IPL Matches 2008-2020.csv")

# %%
ipl
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
ipl1=ipl.fillna('city')
ipl1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl1.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic['L_name']=titanic.Name.str.split(',').str.get(0)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
